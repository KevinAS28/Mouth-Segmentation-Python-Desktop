# %%
import cv2

# %%
def find_border_contours(gray_img):
    blur = cv2.GaussianBlur(gray_img, (5,5), 0)
    thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (15,15))
    dilate = cv2.dilate(thresh, kernel, iterations=2)

    cnts = cv2.findContours(dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    print(len(cnts), cnts)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]
    return cnts

img = cv2.imread('mouth.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cnts = find_border_contours(gray)
cv2.drawContours(img, cnts, -1, (0,255,0), 3)
cv2.imwrite('mouth_out_py.png', img)
# Out:
# 2 ((array([[[667, 261]],
#
#        [[666, 262]],
#
#        [[665, 262]],
#
#        [[662, 265]],
#
#        [[662, 266]],
#
#        [[661, 267]],
#
#        [[661, 269]],
#
#        [[660, 270]],
#
#        [[660, 271]],
#
#        [[657, 274]],
#
#        [[657, 275]],
#
#        [[656, 276]],
#
#        [[656, 277]],
#
#        [[655, 278]],
#
#        [[655, 279]],
#
#        [[654, 280]],
#
#        [[654, 282]],
#
#        [[653, 283]],
#
#        [[653, 284]],
#
#        [[652, 285]],
#
#        [[652, 286]],
#
#        [[651, 287]],
#
#        [[651, 288]],
#
#        [[649, 290]],
#
#        [[649, 291]],
#
#        [[648, 292]],
#
#        [[648, 293]],
#
#        [[647, 294]],
#
#        [[647, 296]],
#
#        [[643, 300]],
#
#        [[643, 301]],
#
#        [[642, 302]],
#
#        [[642, 307]],
#
#        [[641, 308]],
#
#        [[641, 309]],
#
#        [[640, 310]],
#
#        [[640, 311]],
#
#        [[639, 312]],
#
#        [[639, 314]],
#
#        [[638, 315]],
#
#        [[638, 316]],
#
#        [[636, 318]],
#
#        [[636, 320]],
#
#        [[634, 322]],
#
#        [[634, 323]],
#
#        [[632, 325]],
#
#        [[632, 328]],
#
#        [[628, 332]],
#
#        [[628, 333]],
#
#        [[627, 334]],
#
#        [[627, 335]],
#
#        [[625, 337]],
#
#        [[625, 338]],
#
#        [[622, 341]],
#
#        [[622, 346]],
#
#        [[616, 352]],
#
#        [[616, 353]],
#
#        [[613, 356]],
#
#        [[613, 357]],
#
#        [[611, 359]],
#
#        [[610, 359]],
#
#        [[608, 361]],
#
#        [[608, 363]],
#
#        [[607, 364]],
#
#        [[607, 366]],
#
#        [[606, 367]],
#
#        [[606, 368]],
#
#        [[603, 371]],
#
#        [[603, 372]],
#
#        [[602, 373]],
#
#        [[602, 374]],
#
#        [[601, 375]],
#
#        [[600, 375]],
#
#        [[599, 376]],
#
#        [[598, 376]],
#
#        [[597, 377]],
#
#        [[597, 378]],
#
#        [[596, 379]],
#
#        [[596, 380]],
#
#        [[590, 386]],
#
#        [[590, 391]],
#
#        [[589, 392]],
#
#        [[589, 393]],
#
#        [[587, 395]],
#
#        [[587, 396]],
#
#        [[586, 397]],
#
#        [[585, 397]],
#
#        [[584, 398]],
#
#        [[583, 398]],
#
#        [[582, 399]],
#
#        [[581, 399]],
#
#        [[580, 400]],
#
#        [[579, 400]],
#
#        [[576, 403]],
#
#        [[576, 404]],
#
#        [[575, 405]],
#
#        [[575, 406]],
#
#        [[569, 412]],
#
#        [[569, 413]],
#
#        [[568, 414]],
#
#        [[568, 416]],
#
#        [[561, 423]],
#
#        [[561, 426]],
#
#        [[560, 427]],
#
#        [[560, 428]],
#
#        [[558, 430]],
#
#        [[557, 430]],
#
#        [[555, 432]],
#
#        [[555, 433]],
#
#        [[554, 434]],
#
#        [[554, 435]],
#
#        [[553, 436]],
#
#        [[553, 438]],
#
#        [[552, 439]],
#
#        [[552, 440]],
#
#        [[551, 441]],
#
#        [[551, 442]],
#
#        [[550, 443]],
#
#        [[550, 444]],
#
#        [[549, 445]],
#
#        [[549, 446]],
#
#        [[548, 447]],
#
#        [[548, 448]],
#
#        [[547, 449]],
#
#        [[547, 450]],
#
#        [[545, 452]],
#
#        [[545, 453]],
#
#        [[544, 454]],
#
#        [[544, 455]],
#
#        [[543, 456]],
#
#        [[543, 457]],
#
#        [[542, 458]],
#
#        [[542, 459]],
#
#        [[541, 460]],
#
#        [[541, 461]],
#
#        [[540, 462]],
#
#        [[540, 463]],
#
#        [[539, 464]],
#
#        [[539, 466]],
#
#        [[538, 467]],
#
#        [[538, 469]],
#
#        [[537, 470]],
#
#        [[537, 471]],
#
#        [[536, 472]],
#
#        [[536, 473]],
#
#        [[535, 474]],
#
#        [[535, 475]],
#
#        [[534, 476]],
#
#        [[534, 477]],
#
#        [[533, 478]],
#
#        [[533, 479]],
#
#        [[532, 480]],
#
#        [[532, 481]],
#
#        [[531, 482]],
#
#        [[531, 483]],
#
#        [[530, 484]],
#
#        [[530, 485]],
#
#        [[529, 486]],
#
#        [[529, 487]],
#
#        [[528, 488]],
#
#        [[528, 489]],
#
#        [[527, 490]],
#
#        [[527, 491]],
#
#        [[526, 492]],
#
#        [[526, 494]],
#
#        [[525, 495]],
#
#        [[525, 496]],
#
#        [[524, 497]],
#
#        [[524, 498]],
#
#        [[523, 499]],
#
#        [[523, 500]],
#
#        [[521, 502]],
#
#        [[521, 504]],
#
#        [[520, 505]],
#
#        [[520, 507]],
#
#        [[519, 508]],
#
#        [[519, 509]],
#
#        [[518, 510]],
#
#        [[518, 511]],
#
#        [[517, 512]],
#
#        [[517, 513]],
#
#        [[516, 514]],
#
#        [[516, 515]],
#
#        [[513, 518]],
#
#        [[513, 520]],
#
#        [[512, 521]],
#
#        [[512, 535]],
#
#        [[681, 535]],
#
#        [[681, 261]]], dtype=int32), array([[[318,  31]],
#
#        [[317,  32]],
#
#        [[315,  32]],
#
#        ...,
#
#        [[363,  32]],
#
#        [[350,  32]],
#
#        [[349,  31]]], dtype=int32), array([[[629,   0]],
#
#        [[629,  27]],
#
#        [[630,  28]],
#
#        [[630,  32]],
#
#        [[631,  33]],
#
#        [[631,  35]],
#
#        [[632,  36]],
#
#        [[632,  37]],
#
#        [[633,  38]],
#
#        [[633,  39]],
#
#        [[634,  40]],
#
#        [[634,  41]],
#
#        [[635,  42]],
#
#        [[635,  43]],
#
#        [[637,  45]],
#
#        [[637,  46]],
#
#        [[644,  53]],
#
#        [[645,  53]],
#
#        [[647,  55]],
#
#        [[648,  55]],
#
#        [[649,  56]],
#
#        [[650,  56]],
#
#        [[651,  57]],
#
#        [[652,  57]],
#
#        [[653,  58]],
#
#        [[654,  58]],
#
#        [[655,  59]],
#
#        [[657,  59]],
#
#        [[658,  60]],
#
#        [[662,  60]],
#
#        [[663,  61]],
#
#        [[681,  61]],
#
#        [[681,   0]]], dtype=int32), array([[[548,   0]],
#
#        [[548,  14]],
#
#        [[549,  15]],
#
#        [[549,  16]],
#
#        [[550,  17]],
#
#        [[550,  18]],
#
#        [[551,  19]],
#
#        [[551,  20]],
#
#        [[552,  21]],
#
#        [[552,  22]],
#
#        [[554,  24]],
#
#        [[554,  26]],
#
#        [[556,  28]],
#
#        [[556,  29]],
#
#        [[557,  30]],
#
#        [[557,  32]],
#
#        [[558,  33]],
#
#        [[558,  34]],
#
#        [[559,  35]],
#
#        [[559,  36]],
#
#        [[560,  37]],
#
#        [[561,  37]],
#
#        [[562,  38]],
#
#        [[562,  43]],
#
#        [[563,  44]],
#
#        [[563,  46]],
#
#        [[564,  47]],
#
#        [[564,  48]],
#
#        [[565,  49]],
#
#        [[567,  49]],
#
#        [[568,  50]],
#
#        [[568,  57]],
#
#        [[569,  58]],
#
#        [[569,  59]],
#
#        [[597,  59]],
#
#        [[597,  29]],
#
#        [[596,  28]],
#
#        [[596,  27]],
#
#        [[595,  27]],
#
#        [[594,  26]],
#
#        [[594,  20]],
#
#        [[593,  19]],
#
#        [[593,  17]],
#
#        [[590,  14]],
#
#        [[589,  14]],
#
#        [[588,  13]],
#
#        [[588,   6]],
#
#        [[587,   5]],
#
#        [[587,   3]],
#
#        [[585,   1]],
#
#        [[585,   0]]], dtype=int32)), array([[[ 1, -1, -1, -1],
#         [ 2,  0, -1, -1],
#         [ 3,  1, -1, -1],
#         [-1,  2, -1, -1]]], dtype=int32))
# True
